# %%
# !pip install scikit-surprise
# Out:
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.3.tar.gz (771 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.4)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3163757 sha256=fc42b630fb690f8111d42adf10a6a6dce78bbc67b17f659eb682e6421f6736b8
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.3

# %%
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise import Reader

reader = Reader()
data = Dataset.load_builtin('ml-100k')
# Out:
# Dataset ml-100k could not be found. Do you want to download it? [Y/n] y
# Trying to download dataset from https://files.grouplens.org/datasets/movielens/ml-100k.zip...
# Done! Dataset ml-100k has been saved to /root/.surprise_data/ml-100k

# %%
from surprise import KNNWithMeans, KNNBasic
from surprise.model_selection import GridSearchCV
from surprise.model_selection import train_test_split

# min_support parameter can determine the minimum number of ratings or interactions a user or item needs to have before being considered for recommendations.
sim_options = {
    "name": ["msd", "cosine"],
    "min_support": [1, 5],
    "user_based": [True],
}
param_grid = {
    "k": [10, 25, 40],
    "min_k": [1, 2],
    "sim_options": sim_options
}

gs = GridSearchCV(KNNWithMeans, param_grid, measures=["rmse", "mae"], cv=3)
gs.fit(data)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
print("GS Best RMSE: ", gs.best_score["rmse"])
print("GS Best MAE: ", gs.best_score["mae"])
# Out:
# GS Best RMSE:  0.9530450493915619
# GS Best MAE:  0.750018119771128

# %%
gs.best_params['rmse']
# Out:
# {'k': 40,
#  'min_k': 2,
#  'sim_options': {'name': 'msd', 'min_support': 5, 'user_based': True}}

# %%
gs.best_params['mae']
# Out:
# {'k': 40,
#  'min_k': 2,
#  'sim_options': {'name': 'msd', 'min_support': 5, 'user_based': True}}

# %%
algo = gs.best_estimator["rmse"]
trainset = data.build_full_trainset()
algo.fit(trainset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
testset = trainset.build_anti_testset()

predictions = algo.test(testset)

# %%
# r_ui = actual rating
# est = estimated rating
for pred in predictions[:25]:
  print(pred)
# Out:
# user: 196        item: 302        r_ui = 3.53   est = 4.03   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 377        r_ui = 3.53   est = 2.44   {'actual_k': 13, 'was_impossible': False}
# user: 196        item: 51         r_ui = 3.53   est = 3.35   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 346        r_ui = 3.53   est = 3.81   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 474        r_ui = 3.53   est = 4.32   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 265        r_ui = 3.53   est = 3.72   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 465        r_ui = 3.53   est = 3.63   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 451        r_ui = 3.53   est = 3.54   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 86         r_ui = 3.53   est = 3.96   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 1014       r_ui = 3.53   est = 3.34   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 222        r_ui = 3.53   est = 3.60   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 40         r_ui = 3.53   est = 2.96   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 29         r_ui = 3.53   est = 2.73   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 785        r_ui = 3.53   est = 3.30   {'actual_k': 39, 'was_impossible': False}
# user: 196        item: 387        r_ui = 3.53   est = 3.59   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 274        r_ui = 3.53   est = 3.51   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 1042       r_ui = 3.53   est = 3.40   {'actual_k': 27, 'was_impossible': False}
# user: 196        item: 1184       r_ui = 3.53   est = 2.84   {'actual_k': 9, 'was_impossible': False}
# user: 196        item: 392        r_ui = 3.53   est = 3.57   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 486        r_ui = 3.53   est = 3.74   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 144        r_ui = 3.53   est = 3.64   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 118        r_ui = 3.53   est = 3.12   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 1          r_ui = 3.53   est = 3.82   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 546        r_ui = 3.53   est = 2.83   {'actual_k': 40, 'was_impossible': False}
# user: 196        item: 95         r_ui = 3.53   est = 3.86   {'actual_k': 40, 'was_impossible': False}
